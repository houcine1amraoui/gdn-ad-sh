# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !rm -rf gdn-ad-sh
# !git clone https://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@github.com/houcine1amraoui/gdn-ad-sh.git
# %cd gdn-ad-sh
# Out:
# Cloning into 'gdn-ad-sh'...
# remote: Enumerating objects: 1556, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 1556 (delta 188), reused 192 (delta 94), pack-reused 1263 (from 1)
# Receiving objects: 100% (1556/1556), 772.66 KiB | 23.41 MiB/s, done.
# Resolving deltas: 100% (1055/1055), done.
# /content/gdn-ad-sh

# %%
import yaml
from pathlib import Path

config_override = {
    "project_root_dir": "/content/drive/MyDrive/02_research/td_gdn",
    "seed": 42,

    "dataset": {
        "merge_bre_cu": False,
        "dataset_name": "BRE",
        "dataset_folder": "data"
    },

    # actor timelines
    "actor1_t1_start": "2022-10-18 00:00:00",
    "actor1_t1_end": "2022-11-07 23:59:59",
    "actor2_start": "2022-11-08 00:00:00",
    "actor2_end": "2022-11-10 23:59:59",
    "actor1_t2_start": "2022-11-11 00:00:00",
    "actor1_t2_end": "2022-11-17 23:59:59",

    "preprocessing": {
        "apply_filtering": False,
        "apply_cleaning": True,
        "downsample_freq": "1s",
        "val_ratio": 0.2
    },

    "models": [
        {
            "name": "gdn",
            "enabled": True,
            "params": {
                "hidden_dim": 64,
                "topk": 15,
                "heads": 1
            }
        },
        {
            "name": "mtad_gat",
            "enabled": True,
            "params": {
                "kernel_size": 5,
                "gru_hidden_dim": 100,
                "gat_heads": 2
            }
        }
    ],

    "training": {
        "model": "gdn",
        "window_size": 50,
        "batch_size": 64,
        "epochs": 50,
        "lr": 0.001,
        "patience": 10
    },

    "evaluation": {
        "model": "gdn",
        "batch_size": 64,
        "threshold_percentile": 99
    }
}
repo_path = "/content/gdn-ad-sh"
config_path = Path(repo_path) / "configs/config.yaml"

with open(config_path, "w") as f:
    yaml.dump(config_override, f, sort_keys=False)

print("config.yaml overridden successfully")
# Out:
# config.yaml overridden successfully

# %%
from IPython.display import clear_output
import torch

# !pip install torch-geometric

if torch.cuda.is_available():
  # !pip install torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cu128.html
else:
  # !pip install torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cpu.html

clear_output()

# %%
# !python -m main_preprocess
# Out:
# /content/drive/MyDrive/02_research/td_gdn
# Loading BRE data...
# nbr of devices: 94
# Actor split done.
# Normalization done.
# 1451520 362880 259200 597587
# Preprocessing Done.

# %%
# !python -m main_train
# Out:
#   0% 0/50 [00:00<?, ?it/s]Epoch 1 | LR: 0.001000 | Train Loss: 0.008234 | Val Loss: 0.015418
#   2% 1/50 [04:26<3:37:32, 266.39s/it]Epoch 2 | LR: 0.001000 | Train Loss: 0.005658 | Val Loss: 0.014144
#   4% 2/50 [08:40<3:27:21, 259.19s/it]Epoch 3 | LR: 0.001000 | Train Loss: 0.005182 | Val Loss: 0.019694
#   6% 3/50 [12:54<3:21:16, 256.96s/it]Epoch 4 | LR: 0.001000 | Train Loss: 0.004937 | Val Loss: 0.092519
#   8% 4/50 [17:09<3:16:22, 256.13s/it]

# %%
# !python -m main_evaluation
