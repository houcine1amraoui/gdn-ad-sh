# %%
# Check GPU
import torch
print("GPU available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# GPU available: False
# GPU: None

# %%
# !rm -rf gdn-ad-sh
# !git clone https://github.com/houcine1amraoui/gdn-ad-sh
# %cd gdn-ad-sh
# Out:
# Cloning into 'gdn-ad-sh'...
# remote: Enumerating objects: 349, done.
# remote: Counting objects: 100% (349/349), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 349 (delta 172), reused 263 (delta 89), pack-reused 0 (from 0)
# Receiving objects: 100% (349/349), 375.69 KiB | 12.95 MiB/s, done.
# Resolving deltas: 100% (172/172), done.
# /content/gdn-ad-sh/gdn-ad-sh

# %%
# !pip install torch-geometric

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/02_research/dyg_home/data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# processed  raw	sample

# %%
DATA_PATH = "/content/drive/MyDrive/02_research/dyg_home/data/raw/BREMaster.csv"
PROCESSED_DATA_FOLDER_PATH = "/content/drive/MyDrive/02_research/dyg_home/data/processed"
CHECKPOINT_PATH = "/content/drive/MyDrive/checkpoints"

# %%
# !python -m main_preprocess --data_path $DATA_PATH --processed_folder $PROCESSED_DATA_FOLDER_PATH
# Out:
# hhhhhhhhhhhhhhhhhhhhhhhhhh /content/drive/MyDrive/02_research/dyg_home/data/processed
# Preprocessing Done.
